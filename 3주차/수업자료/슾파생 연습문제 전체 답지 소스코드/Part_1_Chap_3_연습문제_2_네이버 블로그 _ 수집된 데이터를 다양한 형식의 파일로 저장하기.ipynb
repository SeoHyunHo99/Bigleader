# %%
# 네이버 블로그 정보 수집하여 저장하기

print("=" *80)
print(" 연습문제 : 저장할 내용을 목록으로 만들어서 xls , csv 형식으로 저장하기")
print("=" *80)

#Step 0. 필요한 모듈과 라이브러리를 로딩하고 검색어를 입력 받습니다

from bs4 import BeautifulSoup
from selenium import webdriver
import time
import sys        # system 설정을 변경하기 위해 필요합니다
import math
import pandas  as pd    

query_txt = input('1.크롤링할 키워드는 무엇입니까?: ')
cnt=int(input('2.수집할 데이터는 몇 건입니까?: ') )
page_cnt = math.ceil(cnt / 10)

fc_name=input('3.csv 형태로 저장할 경로와 파일명을 확장자 포함해서 쓰세요(예:c:\\temp\\naver.csv): ')
fx_name=input('4.xls 형태로 저장할 경로와 파일명을 확장자 포함해서 쓰세요(예:c:\\temp\\naver.xls): ')

#Step 1. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.
path = "c:/temp/chromedriver_85/chromedriver.exe"
driver = webdriver.Chrome(path)

driver.get('http://www.naver.com')
time.sleep(2)

#Step 2. 네이버 검색창에 입력 받은 검색어를 넣고 검색한 후 "블로그" 선택
element = driver.find_element_by_id("query")
element.send_keys(query_txt)
element.submit()

driver.find_element_by_link_text("블로그").click( )

# Step 9. 저장 목록을 만든 후 목록에 있는 내용을 파일에 저장하기

no2 = [ ]           # 게시글 번호 컬럼
title2 = [ ]        # 게시물 제목 컬럼
contents2 = [ ]     # 게시글 내용 컬럼
bdate2 = [ ]        # 작성 일자 컬럼
nick2 = [ ]         # 블로그 닉네임

no = 1

for a in range(1, page_cnt + 1) :
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    blog_list = soup.select('ul > li > dl')
    #blog_list = soup.find('ul','type01').find_all('li')
        
    for i in blog_list:

        no2.append(no)                            # 게시물 번호 리스트에 추가
        print('1.번호:',no)

        title = i.find('dt').get_text( )          # 게시물 제목
        title2.append(title)                      # 게시물 제목 리스트에 추가
        print('2.제목:',title)

        contents = i.find('dd' , 'sh_blog_passage').get_text( )   # 게시물 내용
        contents2.append(contents)                # 게시물 내용 리스트에 추가
        print('3.내용:',contents)

        bdate = i.find('dd','txt_inline').get_text( )  # 작성일자
        bdate2.append(bdate)                     # 작성일자 리스트에 추가
        print('4.작성일자:',bdate)

        nick = i.find('dd','txt_block').find('a').get_text( )
        nick2.append(nick)
        print('5.닉네임:',nick)

        print("\n")

        no += 1

# 출력 결과를 표(데이터 프레임) 형태로 만들기

naver_blog = pd.DataFrame()
naver_blog['번호'] = no2
naver_blog['제목'] = title2
naver_blog['내용'] = contents2
naver_blog['작성일자'] = bdate2
naver_blog['블로그닉네임'] = nick2

# csv 형태로 저장하기
naver_blog.to_csv(fc_name,encoding="utf-8-sig",index=False)
print(" csv 파일 저장 경로: %s" %fc_name) 

# 엑셀 형태로 저장하기
naver_blog.to_excel(fx_name , index=False)
print(" xls 파일 저장 경로: %s" %fx_name)
# Out:
# ================================================================================
#  연습문제 : 저장할 내용을 목록으로 만들어서 xls , csv 형식으로 저장하기
# ================================================================================
# 1.크롤링할 키워드는 무엇입니까?: 서진수 빅데이터
# 2.수집할 데이터는 몇 건입니까?: 30
# 3.csv 형태로 저장할 경로와 파일명을 확장자 포함해서 쓰세요(예:c:\temp\naver.csv): c:\temp\naver.csv
# 4.xls 형태로 저장할 경로와 파일명을 확장자 포함해서 쓰세요(예:c:\temp\naver.xls): c:\temp\naver.xls
# 1
# 1.번호: 1
# 2.제목: [빅데이터 전문가] 서진수 강사님을 소개합니다.
# 3.내용: 서진수 강사님께서는 빅데이터나 데이터베이스, 컴퓨터 프로그래밍 관련 분야 책인 R까기, R라뷰 등 14권이상 집필하였습니다. 뿐만 아니라, 대학교나 대학원, 그리고 KBS...
# 4.작성일자: 2019.06.11.
# 5.닉네임: 한국정보인재개발원...
#
#
# 2
# 1.번호: 2
# 2.제목: 1강 4차 산업혁명의 이해 – 빅데이터 전문가 서진수
# 3.내용: ● 이 내용은 유튜브에 아이티윌의 "4차 산업혁명과 빅데이터 활용"의 무료 강좌를... 개인의 피부, 근육, 뼈조직 데이터를 분석해서 개인 맞춤 운동화를 만든다. 재봉...
# 4.작성일자: 2018.12.03.
# 5.닉네임: 미래 산업의 추세와...
#
#
# 3
# 1.번호: 3
# 2.제목: 빅데이터 전문가 서진수 대표의 트랜드 분석 강의
# 3.내용: 빅데이터 전문가 서진수 대표님. 빅데이터 강의는 분야를 막론하고 누구든... 미래 빅데이터를 추출하는 것은 기술적으로 그리 어렵지 않다. 오히려 데이터를 어떻게...
# 4.작성일자: 2017.03.07.
# 5.닉네임: 카루의 프리랜서 라...
#
#
# 4
# 1.번호: 4
# 2.제목: 마소캠퍼스 빅데이터 분석 오픈 세미나!(서진수 대표님) 151030
# 3.내용: 진행한 빅데이터 분석 오픈 세미나 강연 후기입니다 진행은 서진수 대표님이... 하락중인 데이터를 보고 어떤 인사이트를 얻을 수 있는지, 차례 차례 알려주셨습니다...
# 4.작성일자: 2015.10.31.
# 5.닉네임: 어쩐지 오늘은
#
#
# 5
# 1.번호: 5
# 2.제목: 소셜포럼] 서진수 대표, 변화의 흐름을 이끄는 빅데이터...
# 3.내용: 창의와 융합의 신(新) 물결 ‘4차 산업혁명’ 변화의 흐름을 이끄는 빅데이터 전문가 서진수 ㈜컨시어지소프트 대표 | ㈜데이터앤피플 대표 언제부터인가 미디어에서...
# 4.작성일자: 2017.08.24.
# 5.닉네임: 신지식인 소셜포럼[...
#
#
# 6
# 1.번호: 6
# 2.제목: 아이티윌과 서진수 강사님( 빅데이터 전문가)의 서울대학교...
# 3.내용: 29일에 서진수 강사님을 모시고 빅데이터 Big Data 알 ( R ) 프로그래밍 데이터 분석 교육 출강교육을 추가 교육을 진행을 하였습니다. 그래서 저 또한 아침이...
# 4.작성일자: 2017.05.30.
# 5.닉네임: 통통호의 IT 백과사...
#
#
# 7
# 1.번호: 7
# 2.제목: 방법, 빅데이터 관리가 가장 기본 <(주)컨시어지소프트 서진수...
# 3.내용: 된 빅데이터 기술 활용법 알린다” ㈜컨시어지소프트, ㈜데이터앤피플 서진수 대표 4차산업혁명과 인공지능을 실과 바늘의 관계에...
# 4.작성일자: 2017.09.25.
# 5.닉네임: 오상헌 기자 월간 인...
#
#
# 8
# 1.번호: 8
# 2.제목: 빅데이터 활용으로 4차산업시대를 준비하자_서진수대표 특강...
# 3.내용: 스몰데이터만으로도 충분히 고객관리가 가능합니다. ^^ 그렇게 지난 날의 관심과 열정을 떠올리며, 서진수대표님의 빅데이터 활용 특강을 갔습니다. 아재개그,,,,,를...
# 4.작성일자: 2017.02.28.
# 5.닉네임: 위드앤교육컨설팅_퍼...
#
#
# 9
# 1.번호: 9
# 2.제목: 빅데이터 분석, 웹크롤링 강남 아이티윌과 서진수 강사님의 특강
# 3.내용: 오늘은 강남 아이티윌과 서진수 강사님의 빅데이터분석을 위한 R의 활용방안과 텍스트 마이닝, 데이터 시각화, 통계 패키지의 활용, 데이터 수집을 위한 크롤링 등의...
# 4.작성일자: 2017.08.08.
# 5.닉네임: 우수훈련기관 아이티...
#
#
# 10
# 1.번호: 10
# 2.제목: 빅데이터 전문가 서진수 강사님의 빅데이터 활용과 4차산업에...
# 3.내용: 서진수 강사님의 빅데이터 관련 강의를 들으러 강남을 다녀왔드랬죠!! 빅데이터 전문가라고 하면 사실 카카오다음의 '그 분'을 떠올리실텐데요..ㅋㅋ 서진수 강사님도...
# 4.작성일자: 2017.02.27.
# 5.닉네임: 한결다온교육연구소
#
#
# 11
# 1.번호: 11
# 2.제목: [빅데이터 전문가] 서진수 강사님을 소개합니다.
# 3.내용: 서진수 강사님께서는 빅데이터나 데이터베이스, 컴퓨터 프로그래밍 관련 분야 책인 R까기, R라뷰 등 14권이상 집필하였습니다. 뿐만 아니라, 대학교나 대학원, 그리고 KBS...
# 4.작성일자: 2019.06.11.
# 5.닉네임: 한국정보인재개발원...
#
#
# 12
# 1.번호: 12
# 2.제목: 1강 4차 산업혁명의 이해 – 빅데이터 전문가 서진수
# 3.내용: ● 이 내용은 유튜브에 아이티윌의 "4차 산업혁명과 빅데이터 활용"의 무료 강좌를... 개인의 피부, 근육, 뼈조직 데이터를 분석해서 개인 맞춤 운동화를 만든다. 재봉...
# 4.작성일자: 2018.12.03.
# 5.닉네임: 미래 산업의 추세와...
#
#
# 13
# 1.번호: 13
# 2.제목: 빅데이터 전문가 서진수 대표의 트랜드 분석 강의
# 3.내용: 빅데이터 전문가 서진수 대표님. 빅데이터 강의는 분야를 막론하고 누구든... 미래 빅데이터를 추출하는 것은 기술적으로 그리 어렵지 않다. 오히려 데이터를 어떻게...
# 4.작성일자: 2017.03.07.
# 5.닉네임: 카루의 프리랜서 라...
#
#
# 14
# 1.번호: 14
# 2.제목: 마소캠퍼스 빅데이터 분석 오픈 세미나!(서진수 대표님) 151030
# 3.내용: 진행한 빅데이터 분석 오픈 세미나 강연 후기입니다 진행은 서진수 대표님이... 하락중인 데이터를 보고 어떤 인사이트를 얻을 수 있는지, 차례 차례 알려주셨습니다...
# 4.작성일자: 2015.10.31.
# 5.닉네임: 어쩐지 오늘은
#
#
# 15
# 1.번호: 15
# 2.제목: 소셜포럼] 서진수 대표, 변화의 흐름을 이끄는 빅데이터...
# 3.내용: 창의와 융합의 신(新) 물결 ‘4차 산업혁명’ 변화의 흐름을 이끄는 빅데이터 전문가 서진수 ㈜컨시어지소프트 대표 | ㈜데이터앤피플 대표 언제부터인가 미디어에서...
# 4.작성일자: 2017.08.24.
# 5.닉네임: 신지식인 소셜포럼[...
#
#
# 16
# 1.번호: 16
# 2.제목: 아이티윌과 서진수 강사님( 빅데이터 전문가)의 서울대학교...
# 3.내용: 29일에 서진수 강사님을 모시고 빅데이터 Big Data 알 ( R ) 프로그래밍 데이터 분석 교육 출강교육을 추가 교육을 진행을 하였습니다. 그래서 저 또한 아침이...
# 4.작성일자: 2017.05.30.
# 5.닉네임: 통통호의 IT 백과사...
#
#
# 17
# 1.번호: 17
# 2.제목: 방법, 빅데이터 관리가 가장 기본 <(주)컨시어지소프트 서진수...
# 3.내용: 된 빅데이터 기술 활용법 알린다” ㈜컨시어지소프트, ㈜데이터앤피플 서진수 대표 4차산업혁명과 인공지능을 실과 바늘의 관계에...
# 4.작성일자: 2017.09.25.
# 5.닉네임: 오상헌 기자 월간 인...
#
#
# 18
# 1.번호: 18
# 2.제목: 빅데이터 활용으로 4차산업시대를 준비하자_서진수대표 특강...
# 3.내용: 스몰데이터만으로도 충분히 고객관리가 가능합니다. ^^ 그렇게 지난 날의 관심과 열정을 떠올리며, 서진수대표님의 빅데이터 활용 특강을 갔습니다. 아재개그,,,,,를...
# 4.작성일자: 2017.02.28.
# 5.닉네임: 위드앤교육컨설팅_퍼...
#
#
# 19
# 1.번호: 19
# 2.제목: 빅데이터 분석, 웹크롤링 강남 아이티윌과 서진수 강사님의 특강
# 3.내용: 오늘은 강남 아이티윌과 서진수 강사님의 빅데이터분석을 위한 R의 활용방안과 텍스트 마이닝, 데이터 시각화, 통계 패키지의 활용, 데이터 수집을 위한 크롤링 등의...
# 4.작성일자: 2017.08.08.
# 5.닉네임: 우수훈련기관 아이티...
#
#
# 20
# 1.번호: 20
# 2.제목: 빅데이터 전문가 서진수 강사님의 빅데이터 활용과 4차산업에...
# 3.내용: 서진수 강사님의 빅데이터 관련 강의를 들으러 강남을 다녀왔드랬죠!! 빅데이터 전문가라고 하면 사실 카카오다음의 '그 분'을 떠올리실텐데요..ㅋㅋ 서진수 강사님도...
# 4.작성일자: 2017.02.27.
# 5.닉네임: 한결다온교육연구소
#
#
# 21
# 1.번호: 21
# 2.제목: [빅데이터 전문가] 서진수 강사님을 소개합니다.
# 3.내용: 서진수 강사님께서는 빅데이터나 데이터베이스, 컴퓨터 프로그래밍 관련 분야 책인 R까기, R라뷰 등 14권이상 집필하였습니다. 뿐만 아니라, 대학교나 대학원, 그리고 KBS...
# 4.작성일자: 2019.06.11.
# 5.닉네임: 한국정보인재개발원...
#
#
# 22
# 1.번호: 22
# 2.제목: 1강 4차 산업혁명의 이해 – 빅데이터 전문가 서진수
# 3.내용: ● 이 내용은 유튜브에 아이티윌의 "4차 산업혁명과 빅데이터 활용"의 무료 강좌를... 개인의 피부, 근육, 뼈조직 데이터를 분석해서 개인 맞춤 운동화를 만든다. 재봉...
# 4.작성일자: 2018.12.03.
# 5.닉네임: 미래 산업의 추세와...
#
#
# 23
# 1.번호: 23
# 2.제목: 빅데이터 전문가 서진수 대표의 트랜드 분석 강의
# 3.내용: 빅데이터 전문가 서진수 대표님. 빅데이터 강의는 분야를 막론하고 누구든... 미래 빅데이터를 추출하는 것은 기술적으로 그리 어렵지 않다. 오히려 데이터를 어떻게...
# 4.작성일자: 2017.03.07.
# 5.닉네임: 카루의 프리랜서 라...
#
#
# 24
# 1.번호: 24
# 2.제목: 마소캠퍼스 빅데이터 분석 오픈 세미나!(서진수 대표님) 151030
# 3.내용: 진행한 빅데이터 분석 오픈 세미나 강연 후기입니다 진행은 서진수 대표님이... 하락중인 데이터를 보고 어떤 인사이트를 얻을 수 있는지, 차례 차례 알려주셨습니다...
# 4.작성일자: 2015.10.31.
# 5.닉네임: 어쩐지 오늘은
#
#
# 25
# 1.번호: 25
# 2.제목: 소셜포럼] 서진수 대표, 변화의 흐름을 이끄는 빅데이터...
# 3.내용: 창의와 융합의 신(新) 물결 ‘4차 산업혁명’ 변화의 흐름을 이끄는 빅데이터 전문가 서진수 ㈜컨시어지소프트 대표 | ㈜데이터앤피플 대표 언제부터인가 미디어에서...
# 4.작성일자: 2017.08.24.
# 5.닉네임: 신지식인 소셜포럼[...
#
#
# 26
# 1.번호: 26
# 2.제목: 아이티윌과 서진수 강사님( 빅데이터 전문가)의 서울대학교...
# 3.내용: 29일에 서진수 강사님을 모시고 빅데이터 Big Data 알 ( R ) 프로그래밍 데이터 분석 교육 출강교육을 추가 교육을 진행을 하였습니다. 그래서 저 또한 아침이...
# 4.작성일자: 2017.05.30.
# 5.닉네임: 통통호의 IT 백과사...
#
#
# 27
# 1.번호: 27
# 2.제목: 방법, 빅데이터 관리가 가장 기본 <(주)컨시어지소프트 서진수...
# 3.내용: 된 빅데이터 기술 활용법 알린다” ㈜컨시어지소프트, ㈜데이터앤피플 서진수 대표 4차산업혁명과 인공지능을 실과 바늘의 관계에...
# 4.작성일자: 2017.09.25.
# 5.닉네임: 오상헌 기자 월간 인...
#
#
# 28
# 1.번호: 28
# 2.제목: 빅데이터 활용으로 4차산업시대를 준비하자_서진수대표 특강...
# 3.내용: 스몰데이터만으로도 충분히 고객관리가 가능합니다. ^^ 그렇게 지난 날의 관심과 열정을 떠올리며, 서진수대표님의 빅데이터 활용 특강을 갔습니다. 아재개그,,,,,를...
# 4.작성일자: 2017.02.28.
# 5.닉네임: 위드앤교육컨설팅_퍼...
#
#
# 29
# 1.번호: 29
# 2.제목: 빅데이터 분석, 웹크롤링 강남 아이티윌과 서진수 강사님의 특강
# 3.내용: 오늘은 강남 아이티윌과 서진수 강사님의 빅데이터분석을 위한 R의 활용방안과 텍스트 마이닝, 데이터 시각화, 통계 패키지의 활용, 데이터 수집을 위한 크롤링 등의...
# 4.작성일자: 2017.08.08.
# 5.닉네임: 우수훈련기관 아이티...
#
#
# 30
# 1.번호: 30
# 2.제목: 빅데이터 전문가 서진수 강사님의 빅데이터 활용과 4차산업에...
# 3.내용: 서진수 강사님의 빅데이터 관련 강의를 들으러 강남을 다녀왔드랬죠!! 빅데이터 전문가라고 하면 사실 카카오다음의 '그 분'을 떠올리실텐데요..ㅋㅋ 서진수 강사님도...
# 4.작성일자: 2017.02.27.
# 5.닉네임: 한결다온교육연구소
#
#
#  csv 파일 저장 경로: c:\temp\naver.csv
#  xls 파일 저장 경로: c:\temp\naver.xls
