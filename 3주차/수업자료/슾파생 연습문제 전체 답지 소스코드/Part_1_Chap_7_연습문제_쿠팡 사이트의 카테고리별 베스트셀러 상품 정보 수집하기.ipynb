# %%
# 연습문제 7: 쿠팡 분야별 베스트 상품 크롤러
#Step 1. 필요한 모듈과 라이브러리를 로딩합니다.
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import sys
import re
import math
import numpy 
import pandas as pd   
import xlwt 
import random
import os
import urllib.request
import urllib

print("=" *80)
print("  연습문제 : 쿠팡 사이트의 베스트셀러 상품 정보 수집하기 ")
print("=" *80)

query_txt='쿠팡'
query_url='https://www.coupang.com/'

sec = input('''
 1.패션의류/잡화-남성    2.패션의류/잡화-여성   3.뷰티              4.출산/유아동
 5.식품                  6.주방용품             7.생활용품          8.홈인테리어
 9.가전/디지털          10.스포츠/레저         11.자동차용품       12.도서/음반/DVD
13.완구/취미            14.문구/오피스         15.반려동물용품     16.헬스/건강식품


1.위 분야 중에서 자료를 수집할 분야의 번호를  선택하세요: ''')

cnt = int(input('2.크롤링 할 건수는 몇건입니까?: '))
page_cnt = math.ceil(cnt/60)

f_dir = input('3.파일을 저장할 폴더명만 쓰세요(엔터키 입력시 :c:\\temp\\ 아래에 저장됨):')
if f_dir=='' :
    f_dir="c:\\temp\\"

print("\n")

if sec == '1' :
  sec_name='패션의류_잡화-남성'
elif sec =='2' :
  sec_name='패션의류_잡화-여성'
elif sec =='3' :
  sec_name='뷰티'
elif sec =='4' :
  sec_name='출산_유아동'
elif sec =='5' :
  sec_name='식품'
elif sec =='6' :
  sec_name='주방용품'
elif sec =='7' :
  sec_name='생활용품'
elif sec =='8' :
  sec_name='홈인테리어'
elif sec =='9' :
  sec_name='가전_디지털'
elif sec =='10' :
  sec_name='스포츠_레저'
elif sec =='11' :
  sec_name='자동차용품'
elif sec =='12' :
  sec_name='도서_음반_DVD'
elif sec =='13' :
  sec_name='완구_취미'
elif sec =='14' :
  sec_name='문구_오피스'
elif sec =='15' :
  sec_name='반려동물용품'
elif sec =='16' :
  sec_name='헬스_건강식품'


if cnt > 30 :
  print("    요청 건수가 많아서 시간이 약간 소요되오니 잠시만 기다려 주세요~~")
else :
  print("    요청하신 데이터를 수집하고 있으니 잠시만 기다려 주세요~~")

# 저장될 파일위치와 이름을 지정합니다
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

os.makedirs(f_dir+s+'-'+query_txt+'-'+sec_name)
os.chdir(f_dir+s+'-'+query_txt+'-'+sec_name)

ff_dir=f_dir+s+'-'+query_txt+'-'+sec_name
ff_name=f_dir+s+'-'+query_txt+'-'+sec_name+'\\'+s+'-'+query_txt+'-'+sec_name+'.txt'
fc_name=f_dir+s+'-'+query_txt+'-'+sec_name+'\\'+s+'-'+query_txt+'-'+sec_name+'.csv'
fx_name=f_dir+s+'-'+query_txt+'-'+sec_name+'\\'+s+'-'+query_txt+'-'+sec_name+'.xls'

img_dir = ff_dir+"\\images"
os.makedirs(img_dir)
os.chdir(img_dir)

s_time = time.time( )

# Step 2. 크롬 드라이버 설정 
chrome_path = "c:/temp/chromedriver_240/chromedriver.exe"
driver = webdriver.Chrome(chrome_path)
query_url='https://www.coupang.com/'
driver.get(query_url)
time.sleep(5)

# 분야별 더보기 버튼을 눌러 페이지를 엽니다
driver.find_element_by_xpath("""//*[@id="header"]/div""").click( )

if sec == '1' :   # 남성패션
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[1]/a""").click( )
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[1]/div/div/ul/li[2]/a""").click()
elif sec == '2' :  #여성패션
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[1]/a""").click( )
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[1]/div/div/ul/li[1]/a""").click()
elif sec == '3' :   #뷰티
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[2]/a""").click( )
elif sec == '4' :    #출산_유아동
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[3]/a""").click( )
elif sec == '5' :    #식품
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[4]/a""").click( )
elif sec == '6' :    #주방용품
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[5]/a""").click( )
elif sec == '7' :    #생활용품
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[6]/a""").click( )
elif sec == '8' :    #홈인테리어
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[7]/a""").click( )
elif sec == '9' :    #가전디지털
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[8]/a""").click( )
elif sec == '10' :   #스포츠레저
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[9]/a""").click( )
elif sec == '11' :   #자동차용품
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[10]/a""").click( )
elif sec == '12' :   #도서음반DVD
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[11]/a""").click( )
elif sec == '13' :   # 완구취미
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[12]/a""").click( )
elif sec == '14' :  #문구오피스
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[13]/a""").click( )
elif sec == '15' :   #반려동물
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[14]/a""").click( )
elif sec == '16' :   #헬스건강
  driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[15]/a""").click( )

#Step 5. 화면을 스크롤해서 아래로 이동합니다

def scroll_down(driver):
  driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
  time.sleep(1)

scroll_down(driver)

ranking2=[]
title2=[]
o_price2=[]
p_price2=[]
discount2 = []
rocket2=[]
soldout2=[]
score2=[]
sat_count2=[]

count = 1
file_no = 1

#Step 6. 내용을 수집합니다
print("\n")
print("===== 곧 수집된 결과를 출력합니다 ^^ ===== ")
print("\n")

time.sleep(2)

for x in range(1,page_cnt + 1) :
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    #이미지 추출하기
    img_src2=[]   # 이미지 URL 저장변수
    
    item_result = soup.find('ul','baby-product-list')
    item_result2 = item_result.find_all('li')

    for li in item_result2:

            if count > cnt :
                break

            try :
                photo = li.find('dt','image').find('img')['src']
            except AttributeError :
                continue
                
            full_photo = 'https:' + photo
            urllib.request.urlretrieve(full_photo,str(file_no)+'.jpg')
            time.sleep(0.5)

            if  file_no > cnt :
                break

            f = open(ff_name, 'a',encoding='UTF-8')
            f.write("-----------------------------------------------------"+"\n")
            print("-" *70)
            
            ranking = count
            print("1.판매순위:",ranking)
            f.write('1.판매순위:'+ str(ranking) + "\n")

            try :
                t = li.find('div',class_='name').get_text().replace("\n","")
            except  :
                title = '제품소개가 없습니다'
                print(title.replace("\n",""))
                f.write('2.제품소개:'+ title + "\n")
            else :
                title = t.replace("\n","").strip()
                print("2.제품소개:", title.replace("\n","").strip())                  
                f.write('2.제품소개:'+ title + "\n")

            try :
                p_price = li.find('strong','price-value').get_text().replace("\n","")
            except  :
                p_price = '0'
                print("3.판매가격:", p_price.replace("\n",""))
                f.write('3.판매가격:'+ p_price + "\n")
            else :
                print("3.판매가격:", p_price.replace("\n",""))
                f.write('3.판매가격:'+ p_price + "\n")

            try :
                o_price = li.find('del','base-price').get_text().replace("\n","")
            except  :
                o_price = p_price
                print("4.원래가격:",o_price.replace("\n",""))
                f.write('4.원래가격:'+ o_price + "\n")
            else :
                print("4.원래가격:",o_price.replace("\n",""))
                f.write('4.원래가격:'+ o_price + "\n")

            try :
                discount = li.find('span','discount-percentage').get_text().replace("\n","")
            except  :
                discount = '0'
                print("5:할인률:", discount)
                f.write('5.할인율:'+ discount + "\n")
            else :
                print("5:할인률:", discount)
                f.write('5.할인율:'+ discount + "\n")

            try :
                rocket = li.find('span','badge rocket').find('img')['alt']
            except  :
                rocket = ''
                print("6:로켓배송여부:", rocket)
                f.write('6:로켓배송여부:'+ rocket + "\n")
            else :
                print("6:로켓배송여부:", rocket)
                f.write('6:로켓배송여부:'+ rocket + "\n")

            try :
                soldout = li.find('div','out-of-stock').get_text().replace("\n","").strip()
            except :
                soldout = ''
                print("7:품절여부:", soldout)
                f.write('7.품절여부:'+ soldout + "\n")
            else :
                print("7:품절여부:", soldout)
                f.write('7.품절여부:'+ soldout + "\n")

            try :
                sat_count = li.find('span','rating-total-count').get_text().replace("(","").replace(")","")
            except  :
                sat_count='0'
                print('8.상품평수: ',sat_count)
                f.write('8.상품평수:'+ sat_count + "\n")
            else :
                print('8.상품평수:',sat_count)
                f.write('8.상품평수:'+ sat_count + "\n")

            try :
                score= li.find('em','rating').get_text()
            except  :
                score='0'
                print('9.평점: 5.0 /',score)
                f.write('9.평점: 5.0 /'+ score + "\n")
            else :     
                print('9.평점: 5.0 /',score)
                f.write('9.평점: 5.0 /'+ score + "\n")

            print("-" *70)

            f.close( )

            time.sleep(0.6)

            ranking2.append(ranking)
            title2.append(title.replace("\n",""))
            o_price2.append(o_price.replace("\n",""))
            p_price2.append(p_price.replace("\n",""))
            rocket2.append(rocket.replace("\n",""))
            soldout2.append(soldout)
            discount2.append(discount)
            score2.append(score)

            try :   
                sat_count2.append(sat_count)
            except IndexError :
                sat_count2.append(0)
                
            count += 1
            file_no += 1
            
    x += 1                
    driver.find_element_by_link_text('%s' %x).click() # 다음 페이지번호 클릭


#step 9. 엑셀 형태로 저장하기

co_best_seller = pd.DataFrame()
co_best_seller['판매순위']=ranking2
co_best_seller['제품소개']=pd.Series(title2)
co_best_seller['제품정가']=pd.Series(o_price2)
co_best_seller['제품판매가']=pd.Series(p_price2)
co_best_seller['할인율']=pd.Series(discount2)
co_best_seller['로켓배송여부']=pd.Series(rocket2)
co_best_seller['상품평수']=pd.Series(sat_count2)
co_best_seller['상품평점']=pd.Series(score2)
co_best_seller['품절여부']=pd.Series(soldout2)


# csv 형태로 저장하기
co_best_seller.to_csv(fc_name,encoding="utf-8-sig",index=True)

# 엑셀 형태로 저장하기
co_best_seller.to_excel(fx_name ,index=True)

e_time = time.time( )
t_time = e_time - s_time

# txt 파일에 크롤링 요약 정보 저장하기
orig_stdout = sys.stdout
f = open(ff_name, 'a',encoding='UTF-8')
sys.stdout = f

print("\n")
print("=" *50)
print("총 소요시간은 %s 초 이며," %t_time)
print("총 저장 건수는 %s 건 입니다 " %count)
print("=" *50)

sys.stdout = orig_stdout
f.close( )

#driver.close( )

count -= 1

print("\n") 
print("=" *80)
print("1.요청된 총 %s 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 %s 건입니다" %(cnt,count))
print("2.총 소요시간은 %s 초 입니다 " %round(t_time,1))
print("3.파일 저장 완료: txt 파일명 : %s " %ff_name)
print("4.파일 저장 완료: csv 파일명 : %s " %fc_name)
print("5.파일 저장 완료: xls 파일명 : %s " %fx_name)
print("=" *80)
print(" 잠시만 기다리시면 수집된 결과가 저장된 엑셀 파일이 자동으로 열립니다~~^^")
print("=" *80)

#이미지 삽입하기

import win32com.client as win32   #pywin32 , pypiwin32 설치후 동작
import win32api  #파이썬 프롬프트를 관리자 권한으로 실행해야 에러없음
                 #파이썬 쉘을 관리자 권한으로 실행한 후 불러오기로 이 소스 실행하기

excel = win32.gencache.EnsureDispatch('Excel.Application')
wb = excel.Workbooks.Open(fx_name)
sheet = wb.ActiveSheet
sheet.Columns(3).ColumnWidth = 30   #  이미지 가로 사이즈에 맞게 컬럼 크기 조정
row_cnt = cnt+1
sheet.Rows("2:%s" %row_cnt).RowHeight = 120  #  이미지 세로 사이즈에 맞게 로우 크기 조정

ws = wb.Sheets("Sheet1")
col_name2=[]
file_name2=[]

for a in range(2,cnt+2) :
    col_name='C'+str(a)
    col_name2.append(col_name)
    time.sleep(0.3)

for b in range(1,cnt+1) :
    file_name=img_dir+'\\'+str(b)+'.jpg'
    file_name2.append(file_name)
    time.sleep(0.3)

for i in range(0,cnt) :
    rng = ws.Range(col_name2[i])
    image = ws.Shapes.AddPicture(file_name2[i], False, True, rng.Left, rng.Top, 130, 100)
    excel.Visible=True
    excel.ActiveWorkbook.Save()
    time.sleep(0.3)
# Out:
# ================================================================================
#   연습문제 : 쿠팡 사이트의 베스트셀러 상품 정보 수집하기
# ================================================================================
#
#  1.패션의류/잡화-남성    2.패션의류/잡화-여성   3.뷰티              4.출산/유아동
#  5.식품                  6.주방용품             7.생활용품          8.홈인테리어
#  9.가전/디지털          10.스포츠/레저         11.자동차용품       12.도서/음반/DVD
# 13.완구/취미            14.문구/오피스         15.반려동물용품     16.헬스/건강식품
#
#
# 1.위 분야 중에서 자료를 수집할 분야의 번호를  선택하세요: 5
# 2.크롤링 할 건수는 몇건입니까?: 100
# 3.파일을 저장할 폴더명만 쓰세요(엔터키 입력시 :c:\temp\ 아래에 저장됨):c:\temp\
#
#
#     요청 건수가 많아서 시간이 약간 소요되오니 잠시만 기다려 주세요~~
#
#
# ===== 곧 수집된 결과를 출력합니다 ^^ =====
#
#
# ----------------------------------------------------------------------
# 1.판매순위: 1
# 2.제품소개: 맛있는제주 제주은갈치 (냉동), 500g, 1팩
# 3.판매가격: 22,900
# 4.원래가격: 29,900
# 5:할인률: 23%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수:  0
# 9.평점: 5.0 / 0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 2
# 2.제품소개: 일주일 제철 과일, 1세트
# 3.판매가격: 17,900
# 4.원래가격: 19,900
# 5:할인률: 10%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수:  0
# 9.평점: 5.0 / 0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 3
# 2.제품소개: 던킨 딸기 듬뿍 미니도넛 (냉동), 25g, 10개입
# 3.판매가격: 5,500
# 4.원래가격: 6,900
# 5:할인률: 20%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 584
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 4
# 2.제품소개: 탐사수, 500ml, 40개
# 3.판매가격: 7,980
# 4.원래가격: 11,900
# 5:할인률: 32%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 365105
# 9.평점: 5.0 / 5.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 5
# 2.제품소개: 실속 핫도그 4종 세트, 1세트
# 3.판매가격: 9,900
# 4.원래가격: 9,900
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 1498
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 6
# 2.제품소개: 서울우유 1급A우유, 2300ml, 1개
# 3.판매가격: 4,890
# 4.원래가격: 4,980
# 5:할인률: 1%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 59815
# 9.평점: 5.0 / 5.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 7
# 2.제품소개: 곰곰 무항생제 신선한 대란, 30구, 1개
# 3.판매가격: 4,990
# 4.원래가격: 6,130
# 5:할인률: 18%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 5508
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 8
# 2.제품소개: 올품 누룽지 백숙 (냉동), 916g, 1개
# 3.판매가격: 9,800
# 4.원래가격: 10,900
# 5:할인률: 10%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 86
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 9
# 2.제품소개: 하림 커플치킨 통닭 백숙용 (냉장), 550g, 2개
# 3.판매가격: 7,460
# 4.원래가격: 8,990
# 5:할인률: 17%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 1068
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 10
# 2.제품소개: 던킨 바바리안 듬뿍 미니도넛 (냉동), 25g, 10개
# 3.판매가격: 5,500
# 4.원래가격: 6,900
# 5:할인률: 20%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 380
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 11
# 2.제품소개: 곰곰 당도선별 수박, 8kg미만, 1통
# 3.판매가격: 12,290
# 4.원래가격: 17,400
# 5:할인률: 29%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 1444
# 9.평점: 5.0 / 3.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 12
# 2.제품소개: 삼진어묵 옛날모듬어묵, 1000g, 1개
# 3.판매가격: 9,900
# 4.원래가격: 12,600
# 5:할인률: 21%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 4737
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 13
# 2.제품소개: 제주 삼다수, 2L, 18개
# 3.판매가격: 17,620
# 4.원래가격: 17,640
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 25821
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 14
# 2.제품소개: 곰곰 호주산 소고기 안창살 구이용 (냉장), 300g, 1개
# 3.판매가격: 10,350
# 4.원래가격: 12,750
# 5:할인률: 18%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 1743
# 9.평점: 5.0 / 4.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 15
# 2.제품소개: 농심 신라면 120g x 5p + 안성탕면 125g x 5p + 얼큰 너구리 120g x 5p + 짜파게티 140g x 5p, 1세트
# 3.판매가격: 14,200
# 4.원래가격: 14,200
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 39167
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 16
# 2.제품소개: 워싱턴 체리, 800g, 1개
# 3.판매가격: 13,900
# 4.원래가격: 18,900
# 5:할인률: 26%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 1718
# 9.평점: 5.0 / 4.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 17
# 2.제품소개: 곰곰 무항생제 신선한 특란, 30구, 1개
# 3.판매가격: 5,290
# 4.원래가격: 5,680
# 5:할인률: 6%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 8203
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 18
# 2.제품소개: 곰곰 우유토스트 식빵, 350g, 2개
# 3.판매가격: 3,910
# 4.원래가격: 3,910
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 404
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 19
# 2.제품소개: 셰프초이스 춘천식닭갈비 (냉장), 1kg, 1개
# 3.판매가격: 12,900
# 4.원래가격: 12,900
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 6603
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 20
# 2.제품소개: 곰곰 양념 소불고기 (냉장), 1kg, 1개
# 3.판매가격: 14,990
# 4.원래가격: 14,990
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 8091
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 21
# 2.제품소개: 탐사베이직 수, 2L, 12개
# 3.판매가격: 5,760
# 4.원래가격: 6,300
# 5:할인률: 8%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 722
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 22
# 2.제품소개: 서울우유 비요뜨 초코링 요거트, 143g, 12개
# 3.판매가격: 11,900
# 4.원래가격: 12,230
# 5:할인률: 2%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 9105
# 9.평점: 5.0 / 5.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 23
# 2.제품소개: 안국건강 루테인 지아잔틴 미니 + 쇼핑백, 120캡슐, 1세트
# 3.판매가격: 32,860
# 4.원래가격: 37,400
# 5:할인률: 12%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 233
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 24
# 2.제품소개: 크리스피크림도넛 오리지널 글레이즈드, 47g, 6개
# 3.판매가격: 7,800
# 4.원래가격: 7,800
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 1336
# 9.평점: 5.0 / 5.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 25
# 2.제품소개: 곰곰 납작한 떡갈비, 1000g, 1개
# 3.판매가격: 9,030
# 4.원래가격: 11,240
# 5:할인률: 19%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 1040
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 26
# 2.제품소개: 마니커에프앤지 성너머집 삼계탕, 800g, 2개
# 3.판매가격: 12,100
# 4.원래가격: 15,120
# 5:할인률: 19%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 1230
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 27
# 2.제품소개: 곰곰 부대찌개 (냉동), 1kg, 2개
# 3.판매가격: 12,540
# 4.원래가격: 12,640
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 7474
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 28
# 2.제품소개: 푸른초원 자연우유, 2300ml, 1개
# 3.판매가격: 4,580
# 4.원래가격: 4,580
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 3537
# 9.평점: 5.0 / 5.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 29
# 2.제품소개: 곰곰 노르웨이 간고등어살 1kg, 1개
# 3.판매가격: 10,490
# 4.원래가격: 11,990
# 5:할인률: 12%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 4741
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 30
# 2.제품소개: 곰곰 제주 흑돼지 불고기 (냉장), 500g, 2개
# 3.판매가격: 9,960
# 4.원래가격: 9,960
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 1094
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 31
# 2.제품소개: 대만식 샌드위치 삼색샌드, 80g, 4개
# 3.판매가격: 7,900
# 4.원래가격: 7,900
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 1565
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 32
# 2.제품소개: 쿠팡 브랜드 - 탐사수, 500ml, 20개
# 3.판매가격: 3,680
# 4.원래가격: 6,400
# 5:할인률: 42%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 28101
# 9.평점: 5.0 / 5.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 33
# 2.제품소개: 미국산 체리, 800g, 1팩
# 3.판매가격: 11,340
# 4.원래가격: 14,900
# 5:할인률: 23%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 540
# 9.평점: 5.0 / 4.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 34
# 2.제품소개: 풀무원 얇은피 꽉찬속 고기만두 (냉동), 1kg, 1개
# 3.판매가격: 9,900
# 4.원래가격: 9,900
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 6261
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 35
# 2.제품소개: 곰곰 단백질바, 50g, 12개입
# 3.판매가격: 11,480
# 4.원래가격: 18,000
# 5:할인률: 36%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 4117
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 36
# 2.제품소개: 곰곰 국내산 햇양파, 3kg, 1봉
# 3.판매가격: 4,200
# 4.원래가격: 6,470
# 5:할인률: 35%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 5944
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 37
# 2.제품소개: 곰곰 당도선별 세척사과, 2kg, 1박스
# 3.판매가격: 16,490
# 4.원래가격: 16,490
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 15579
# 9.평점: 5.0 / 4.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 38
# 2.제품소개: 던킨도너츠 햄에그 잉글리쉬 머핀 (냉동), 108g, 4개
# 3.판매가격: 10,200
# 4.원래가격: 11,600
# 5:할인률: 12%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 74
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 39
# 2.제품소개: 충남오감 세도농협 GAP 인증 대추방울토마토, 1kg, 1박스
# 3.판매가격: 9,900
# 4.원래가격: 10,900
# 5:할인률: 9%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 10107
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 40
# 2.제품소개: 제주 탐사수, 2L, 6개
# 3.판매가격: 5,290
# 4.원래가격: 6,900
# 5:할인률: 23%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 2886
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 41
# 2.제품소개: 미각제빵소 프리미엄 생식빵, 500g, 1개
# 3.판매가격: 5,790
# 4.원래가격: 6,790
# 5:할인률: 14%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 2065
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 42
# 2.제품소개: 곰곰 국내산 제육 볶음 (냉장), 400g, 2개
# 3.판매가격: 8,600
# 4.원래가격: 8,600
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 520
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 43
# 2.제품소개: 오리온 입이 심심해 과자세트 564g, 꼬북칩 콘스프맛 30g x 3p + 포카칩 오리지널 30g x 3p + 스윙칩 복음고추장맛 30g x 3p + 오징어땅콩 98g x 3p, 1세트
# 3.판매가격: 8,900
# 4.원래가격: 10,900
# 5:할인률: 18%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 138
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 44
# 2.제품소개: 곰곰 2019년 소중한 우리 쌀, 10kg, 1개
# 3.판매가격: 25,450
# 4.원래가격: 37,400
# 5:할인률: 31%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 63997
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 45
# 2.제품소개: 오뚜기 진비빔면 156g, 4개
# 3.판매가격: 2,360
# 4.원래가격: 2,780
# 5:할인률: 15%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 6566
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 46
# 2.제품소개: 맑은물에 국산콩 100% 촌두부, 300g, 2개
# 3.판매가격: 3,980
# 4.원래가격: 3,980
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 21419
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 47
# 2.제품소개: 팜에이트 레드믹스, 300g, 1팩
# 3.판매가격: 3,750
# 4.원래가격: 4,500
# 5:할인률: 16%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 694
# 9.평점: 5.0 / 4.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 48
# 2.제품소개: 곰곰 국내산 절단대파, 500g, 1개
# 3.판매가격: 2,600
# 4.원래가격: 2,990
# 5:할인률: 13%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 1480
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 49
# 2.제품소개: 곰곰 국내산 신선한 햇감자, 1kg, 1봉
# 3.판매가격: 2,370
# 4.원래가격: 4,660
# 5:할인률: 49%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 6150
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 50
# 2.제품소개: 삼립 로만밀 통밀식빵, 420g, 2개입
# 3.판매가격: 4,160
# 4.원래가격: 4,760
# 5:할인률: 12%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 9889
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 51
# 2.제품소개: 국내산 백오이 5입, 1봉
# 3.판매가격: 3,660
# 4.원래가격: 3,700
# 5:할인률: 1%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 3626
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 52
# 2.제품소개: 곰곰 1등급 훈제 오리 슬라이스 (냉장), 500g, 1개
# 3.판매가격: 7,990
# 4.원래가격: 8,690
# 5:할인률: 8%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 267
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 53
# 2.제품소개: 파프리카 혼합, 1봉
# 3.판매가격: 1,980
# 4.원래가격: 2,490
# 5:할인률: 20%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 2817
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 54
# 2.제품소개: 곰곰 아삭한 콩나물, 500g, 1봉
# 3.판매가격: 1,880
# 4.원래가격: 1,880
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 4782
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 55
# 2.제품소개: 국내산 애호박, 1개
# 3.판매가격: 1,280
# 4.원래가격: 1,280
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 11374
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 56
# 2.제품소개: 하림 닭한마리 칼국수 밀키트, 600g, 1개
# 3.판매가격: 12,460
# 4.원래가격: 12,910
# 5:할인률: 3%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 199
# 9.평점: 5.0 / 4.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 57
# 2.제품소개: 곰곰 팝콘치킨, 1000g, 1개
# 3.판매가격: 7,070
# 4.원래가격: 7,740
# 5:할인률: 8%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 737
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 58
# 2.제품소개: 삼립 리얼 후레쉬 치즈케익 10개입, 700g, 1개
# 3.판매가격: 7,980
# 4.원래가격: 12,730
# 5:할인률: 37%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 5111
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 59
# 2.제품소개: 생생포크 대패 삼겹살 (냉동), 500g, 1개
# 3.판매가격: 9,900
# 4.원래가격: 12,900
# 5:할인률: 23%
# 6:로켓배송여부: 로켓배송
# 7:품절여부: 일시품절
# 8.상품평수: 512
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 60
# 2.제품소개: 당도선별 아삭한 복숭아, 2kg (8~10입), 1박스
# 3.판매가격: 12,900
# 4.원래가격: 14,900
# 5:할인률: 13%
# 6:로켓배송여부: 로켓배송
# 7:품절여부: 일시품절
# 8.상품평수: 35
# 9.평점: 5.0 / 3.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 61
# 2.제품소개: 곰곰 새콤달콤 후무사 자두, 1kg, 1팩
# 3.판매가격: 7,820
# 4.원래가격: 9,990
# 5:할인률: 21%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 489
# 9.평점: 5.0 / 3.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 62
# 2.제품소개: 동원에프앤비 비엔나소시지, 1kg, 1개
# 3.판매가격: 8,980
# 4.원래가격: 12,100
# 5:할인률: 25%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 7179
# 9.평점: 5.0 / 5.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 63
# 2.제품소개: 모아미트 보리먹인 암퇘지 삼겹살 구이용 (냉장), 1kg, 1개
# 3.판매가격: 17,400
# 4.원래가격: 17,400
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 2591
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 64
# 2.제품소개: 곰곰 대추방울토마토, 750g, 1팩
# 3.판매가격: 5,580
# 4.원래가격: 5,930
# 5:할인률: 5%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 5266
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 65
# 2.제품소개: 허닭 닭가슴살 스페셜 패키지 15종 세트 (냉동), 1세트
# 3.판매가격: 29,700
# 4.원래가격: 33,700
# 5:할인률: 11%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 8552
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 66
# 2.제품소개: 던킨 블루베리 듬뿍 미니도넛 (냉동), 25g, 10개
# 3.판매가격: 5,500
# 4.원래가격: 6,900
# 5:할인률: 20%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 199
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 67
# 2.제품소개: 켈로그 첵스 파맛 시리얼, 350g, 1개
# 3.판매가격: 5,980
# 4.원래가격: 5,980
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 631
# 9.평점: 5.0 / 4.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 68
# 2.제품소개: 남양유업 떠먹는 불가리스 세트, 딸기 85g x 6p + 포도 85g x 2p + 복숭아 85g x 2p, 1세트
# 3.판매가격: 4,200
# 4.원래가격: 4,980
# 5:할인률: 15%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 6161
# 9.평점: 5.0 / 5.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 69
# 2.제품소개: 남양유업 맛있는 우유 GT, 900ml, 2개
# 3.판매가격: 4,200
# 4.원래가격: 4,750
# 5:할인률: 11%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 11118
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 70
# 2.제품소개: 자연애찬 자연愛란 무항생제 인증 특란 30구, 1800g, 1개
# 3.판매가격: 5,980
# 4.원래가격: 5,980
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 30454
# 9.평점: 5.0 / 4.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 71
# 2.제품소개: 곰곰 갈비탕, 600g, 5개
# 3.판매가격: 14,870
# 4.원래가격: 14,990
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 10265
# 9.평점: 5.0 / 4.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 72
# 2.제품소개: 곰곰 우삼겹 순두부 찌개, 705g, 1세트
# 3.판매가격: 7,450
# 4.원래가격: 7,490
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 235
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 73
# 2.제품소개: 풀무원 1등급 국산 무농약 콩나물, 340g, 1개
# 3.판매가격: 2,260
# 4.원래가격: 2,300
# 5:할인률: 1%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 4931
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 74
# 2.제품소개: 서울우유 더 진한 플레인 요거트 당무첨가, 1800ml, 1개
# 3.판매가격: 6,100
# 4.원래가격: 6,730
# 5:할인률: 9%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 4631
# 9.평점: 5.0 / 5.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 75
# 2.제품소개: 오리온 초코가 필요해 과자세트 1296g, 과자 6종, 1세트
# 3.판매가격: 17,910
# 4.원래가격: 21,400
# 5:할인률: 16%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 193
# 9.평점: 5.0 / 5.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 76
# 2.제품소개: 아이시스 먹는샘물 랜덤발송, 2L, 12개
# 3.판매가격: 7,880
# 4.원래가격: 7,980
# 5:할인률: 1%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 7296
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 77
# 2.제품소개: 친환경 인증 팽이버섯, 150g, 3팩
# 3.판매가격: 1,180
# 4.원래가격: 1,480
# 5:할인률: 20%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 5507
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 78
# 2.제품소개: 곰곰 돌돌말이 무연골 대패 삼겹살 (냉동), 1kg, 1개
# 3.판매가격: 11,400
# 4.원래가격: 11,400
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 463
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 79
# 2.제품소개: GAP 인증 추부깻잎, 1봉
# 3.판매가격: 1,380
# 4.원래가격: 1,380
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 3623
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 80
# 2.제품소개: 빙그레 바나나맛우유, 240ml, 8개
# 3.판매가격: 8,860
# 4.원래가격: 8,900
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 12328
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 81
# 2.제품소개: 외갓집 송탄 서정리 부대찌개 (냉동), 1kg, 2개
# 3.판매가격: 13,440
# 4.원래가격: 13,440
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 10029
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 82
# 2.제품소개: 참맛나라 신선한 알이 듬뿍 알탕, 1265g, 1개
# 3.판매가격: 12,900
# 4.원래가격: 12,900
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 3853
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 83
# 2.제품소개: 프레시지 더큰 밀푀유 나베, 965g, 1개
# 3.판매가격: 13,900
# 4.원래가격: 13,900
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 6757
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 84
# 2.제품소개: 삼립 아침엔 우유토스트 식빵, 330g, 2개
# 3.판매가격: 3,960
# 4.원래가격: 3,960
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 16874
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 85
# 2.제품소개: 앙트레 쿠킹박스 찹스테이크 2인분, 550g, 1개
# 3.판매가격: 12,880
# 4.원래가격: 15,400
# 5:할인률: 16%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 1026
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 86
# 2.제품소개: 국내산 양배추, 1.5kg 이상, 1통
# 3.판매가격: 2,980
# 4.원래가격: 5,180
# 5:할인률: 42%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 5497
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 87
# 2.제품소개: 비비고 왕교자 (냉동), 1.4kg, 1개
# 3.판매가격: 8,590
# 4.원래가격: 9,720
# 5:할인률: 11%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 11935
# 9.평점: 5.0 / 5.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 88
# 2.제품소개: 재로우 우먼 펨-도필러스 베지 캡, 60개입, 1개
# 3.판매가격: 19,230
# 4.원래가격: 22,200
# 5:할인률: 13%
# 6:로켓배송여부:
# 7:품절여부:
# 8.상품평수: 14234
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 89
# 2.제품소개: 추억의 국민학교 떡볶이 오리지널 (냉동), 600g, 2개
# 3.판매가격: 9,580
# 4.원래가격: 9,800
# 5:할인률: 2%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 9188
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 90
# 2.제품소개: 비비고 소고기 장조림, 125g, 3개
# 3.판매가격: 8,040
# 4.원래가격: 8,980
# 5:할인률: 10%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 1424
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 91
# 2.제품소개: 롯데제과 일품 팥빙수 (냉동), 240ml, 12입
# 3.판매가격: 15,360
# 4.원래가격: 15,360
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 135
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 92
# 2.제품소개: 요플레 오프룻 딸기&알로에, 180ml, 10개
# 3.판매가격: 11,800
# 4.원래가격: 15,000
# 5:할인률: 21%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 303
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 93
# 2.제품소개: 풀무원 한끼 연두부 + 참깨 흑임자 소스, 120g, 6개
# 3.판매가격: 7,500
# 4.원래가격: 9,600
# 5:할인률: 21%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 685
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 94
# 2.제품소개: 제주 삼다수, 2L, 12개
# 3.판매가격: 11,750
# 4.원래가격: 11,760
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 127354
# 9.평점: 5.0 / 5.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 95
# 2.제품소개: Now Foods 실리마린 밀크 시슬 추출물 300mg 베지 캡슐, 1개
# 3.판매가격: 18,610
# 4.원래가격: 47,510
# 5:할인률: 60%
# 6:로켓배송여부:
# 7:품절여부:
# 8.상품평수: 22023
# 9.평점: 5.0 / 5.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 96
# 2.제품소개: 꿀맛나는 세상 흑돼지 양념 불고기 (냉동), 400g, 3팩
# 3.판매가격: 11,900
# 4.원래가격: 11,900
# 5:할인률: 0
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 9967
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 97
# 2.제품소개: 돌 하이 피치 주스 120ml, 복숭아, 32개
# 3.판매가격: 11,840
# 4.원래가격: 14,800
# 5:할인률: 20%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 635
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 98
# 2.제품소개: 종근당건강 락토핏 생유산균 골드, 100g, 3개
# 3.판매가격: 29,550
# 4.원래가격: 30,870
# 5:할인률: 4%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 30130
# 9.평점: 5.0 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 99
# 2.제품소개: 프레시지 더큰 우삼겹 순두부찌개, 1315g, 1개
# 3.판매가격: 9,900
# 4.원래가격: 12,900
# 5:할인률: 23%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 15
# 9.평점: 5.0 / 4.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 100
# 2.제품소개: 오리온 모두의 간식 과자세트 1460g, 과자 6종, 1세트
# 3.판매가격: 19,900
# 4.원래가격: 20,900
# 5:할인률: 4%
# 6:로켓배송여부: 로켓배송
# 7:품절여부:
# 8.상품평수: 75
# 9.평점: 5.0 / 5.0
# ----------------------------------------------------------------------
#
#
# ================================================================================
# 1.요청된 총 100 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 100 건입니다
# 2.총 소요시간은 173.9 초 입니다
# 3.파일 저장 완료: txt 파일명 : c:\temp\2020-07-26-16-19-00-쿠팡-식품\2020-07-26-16-19-00-쿠팡-식품.txt
# 4.파일 저장 완료: csv 파일명 : c:\temp\2020-07-26-16-19-00-쿠팡-식품\2020-07-26-16-19-00-쿠팡-식품.csv
# 5.파일 저장 완료: xls 파일명 : c:\temp\2020-07-26-16-19-00-쿠팡-식품\2020-07-26-16-19-00-쿠팡-식품.xls
# ================================================================================
#  잠시만 기다리시면 수집된 결과가 저장된 엑셀 파일이 자동으로 열립니다~~^^
# ================================================================================
