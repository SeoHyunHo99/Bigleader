# %% [markdown]
# # 마크다운(Markdown) 사용법

# %% [markdown]
# ## 1. 마크다운이란?
#
# Markdown은 텍스트 기반의 마크업언어로 2004년 존그루버에 의해 만들어졌으며 쉽게 쓰고 읽을 수 있으며 HTML로 변환이 가능하다. 특수기호와 문자를 이용한 매우 간단한 구조의 문법을 사용하여 웹에서도 보다 빠르게 컨텐츠를 작성하고 보다 직관적으로 인식할 수 있다. 마크다운이 최근 각광받기 시작한 이유는 깃헙(https://github.com) 덕분이다. 깃헙의 저장소Repository에 관한 정보를 기록하는 README.md는 깃헙을 사용하는 사람이라면 누구나 가장 먼저 접하게 되는 마크다운 문서였다. 마크다운을 통해서 설치방법, 소스코드 설명, 이슈 등을 간단하게 기록하고 가독성을 높일 수 있다는 강점이 부각되면서 점점 여러 곳으로 퍼져가게 된다.

# %% [markdown]
# ### 1.1 마크다운 장점
#
# 1. 간결하다.
# 1. 별도의 도구없이 작성가능하다.
# 1. 다양한 형태로 변환이 가능하다.
# 1. 텍스트(Text)로 저장되기 때문에 용량이 적어 보관이 용이하다.
# 1. 텍스트파일이기 때문에 버전관리시스템을 이용하여 변경이력을 관리할 수 있다.
# 1. 지원하는 프로그램과 플랫폼이 다양하다.

# %% [markdown]
# ### 1.2 마크다운 단점
#
# 1. 표준이 없다.
# 1. 표준이 없기 때문에 도구에 따라서 변환방식이나 생성물이 다르다.
# 1. 모든 HTML 마크업을 대신하지 못한다.

# %% [markdown]
# ### 1.3 자주쓰는 단축키 사용
# - ESC : 셀 편집모드
# - Enter : 글자 편집모드
# - Shift + Enter : 셀 실행하며 새로운 셀 추가
# - Ctrl + Enter : 셀 실행
# - 셀편집모드 (ESC) 에서
#  - Y : 언어 코드 모드
#  - M : 마크 다운 모드
#  - B : 선택된 셀 아래에 셀 추가
#  - A : 선택된 셀 위에 셀 추가

# %% [markdown]
# ---

# %% [markdown]
# ## 2. 문서 골격 잡기
#
# ### 2.1 Header
# __`#` 기호__와 __개수__를 통해 간단히 사용가능 (1~6까지 지원)
# <pre style="background: rgb(230, 230, 230); padding: 0.5rem;">
#     # header1
#     ## header2
#     ### header3
#     #### header4
#     ##### header5
#     ###### header6
# </pre>

# %% [markdown]
# # 글씨크기

# %% [markdown]
# # header1
# ## header2
# ### header3
# #### header4
# ##### header5
# ###### 제목입니다.

# %% [markdown]
# ### 2.1 리스트 작성
# __`+` 기호__ 또는 __숫자 + .__과 __들여쓰기__를 통해 간단히 사용가능
#
# <pre style="background: rgb(230, 230, 230); padding: 0.5rem;">+ 목록1</pre>
#
# + 목록1
#
# <pre style="background: rgb(230, 230, 230); padding: 0.5rem;">
# + 목록1
#     + 목록1-1</pre>
# + 목록1
#     + 목록1-1
#
# <pre style="background: rgb(230, 230, 230); padding: 0.5rem;">
# + 목록1
#     + 목록1-1
#         + 목록1-1-1
#     + 목록1-2
#         + 목록1-2-1</pre>

# %% [markdown]
# + 목록1
#     + 목록1-1
#         + 목록1-1-1
#     + 목록1-2
#         + 목록1-2-1

# %% [markdown]
# + 마크다운 사용하기
#   + 마크다운
#   + 업다운

# %% [markdown]
#
# <pre style="background: rgb(230, 230, 230); padding: 0.5rem;">
# 1. 목록
#     1. 목록
#         1. 목록
#             1. 목록
# </pre>

# %% [markdown]
# 1. 목록
#     1. 목록
#         1. 목록
#             1. 목록

# %% [markdown]
# 1. 수업
#    1. 파이썬
#    1. 넘파이
#    1. 판다스
#       1. 시리즈
#       1. 데이터프레임
#
# 1. 과제
# 1. 실습
# 1. 예습

# %% [markdown]
# ### 2.3 구분선 쓰기
#
# __`---`__(하이픈 기호 세개 이상)을 입력하면 구분선이 추가된다.

# %% [markdown]
# ---
# -----
# ---------
# -----------------------------------------------
# -------

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## 3. 내용 쓰기
#
# ### 3.1 New Line
#     한 줄 개행은 Enter로 되지 않는다. __2번의 space(공백)__를 쓰면 줄바꿈이 가능하다.

# %% [markdown]
# 안녕하세요.
# 파이썬입니다..
#
# 안녕하세요.
# 파이썬입니다.

# %% [markdown]
# 안녕하세요. 고우주입니다.
#
# 안녕하세요.
# 수업을 진행하겠습니다.

# %% [markdown]
# ### 3.2 강조하기
# + ### 3.2.1 Bold
# 강조할 내용을 `_`(언더스코어) 두개로 감싼다.
# `__ 강조 내용__`

# %% [markdown]
# 안녕하세요. __파이썬__입니다.

# %% [markdown]
# 안녕하세요. __고우주__입니다.

# %% [markdown]
# 안녕하세요. **고우주** 입니다.

# %% [markdown]
# + ### 3.2.2 인용구쓰기
# 문장 앞에 `>`를 쓰면 인용구처럼 쓸 수 있다.

# %% [markdown]
# > Hello World!

# %% [markdown]
# > Hello World!

# %% [markdown]
#     여러개의 >를 사용할 수 있고, 다른 기능과 섞어서 사용할 수도 있다.

# %% [markdown]
# >Hi
# >> __Bye__
# >>> # 123
# >>> + one
#     + two
#         + three

# %% [markdown]
# __init__(): 메서드는 초기화할 때 사용된다.
# ` __init__():` 메서드는 초기화할 때 사용된다.

# %% [markdown]
# `np.where`는 조건을 줘서 실행 시키다.

# %% [markdown]
# + ### 3-3-2 block으로 쓰기
# <pre style="background: rgb(230, 230, 230); padding: 0.5rem; display:inline-block;">``` [code] ```</pre> 세 개의 점을 통해 사용가능

# %% [markdown]
# ```
# def __init__(self, x):
#     self.x = x
# ```

# %% [markdown]
#
# ### 3.4 Link 걸기
# 기본적으로 url을 쓰면 링크가 활성화된다.
# www.naver.com
#
# 만약 주소의 이름을 명시하고 싶다면 다음 형식을 쓰면된다.
#
#   `[사용할 이름](url)`

# %% [markdown]
# [구글클래스룸](https://classroom.google.com/u/1/c/MTE2MDEzMDIxMzI3)

# %% [markdown]
# <실습>
# [네이버](https://www.naver.com/)

# %% [markdown]
# ### 3.5 이미지 올리기
# 링크를 걸었던 형식 앞에 !만 붙이면 된다.
# `![이미지 이름](이미지 주소)`

# %% [markdown]
# <실습>
# ![주피터](https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/250px-Jupyter_logo.svg.png)

# %% [markdown]
# ![Jupyter Notebook 실행](https://mijeongjeon.github.io/assets/imgs/180808/image1.png)

# %% [markdown]
# "![140915_r25456.jpg](attachment:140915_r25456.jpg)"

# %% [markdown]
# ### 3.6 특수문자 사용하기
# 사용이 안되는 특수문자는 다음 사이트를 참고하세요.
# http://ccambo.blogspot.com/2017/04/markdown_5.html

# %% [markdown]
# ---
# ## 4. 수식 쓰기
#
# 수식을 입려할 때는 `$`표시를 사용한다.
# ※ __1개__를 사용하면 `inline` , __2개__를 사용하면 `block+가운데` 정렬이 된다.
#
# [참조](https://math.meta.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference)

# %% [markdown]
# <실습>
# $f(x) = x^2$

# %% [markdown]
# $f(x) = x^2$

# %% [markdown]
# $$f(x) = x^2$$

# %% [markdown]
# $$\sum_{i=0}^n i^2 = \frac{(n^2+n)(2n+1)}{6}$$

# %% [markdown]
# ---

# %% [markdown]
# ## 5. html 및 표 작성
#
# + HTML문법도 사용 가능하다.
# + 표를 작성하고 싶다면 다음 사이트를 확인해보세요.
#     + http://www.tablesgenerator.com/markdown_tables#

# %% [markdown]
# | \\ 	| 1 	| 2 	| 3 	| 4 	|
# |----	|---	|---	|---	|---	|
# | 1  	| A 	| B 	| C 	| D 	|
# | 2  	| E 	| F 	| G 	| H 	|
# | 3  	| I 	| J 	| K 	| L 	|

# %% [markdown]
# | number |    |
# |--- |--- |
# |1   |A   |
# |2   |E   |

# %% [markdown]
# | \\ 	| 1  	| 2  	| 3 	| 4 	|
# |----	|----	|----	|---	|---	|
# | 1  	| 가 	| 나 	| C 	| D 	|
# | 2  	| E  	| F  	| G 	| H 	|
# | 3  	| I  	| J  	| K 	| L 	|

# %% [markdown]
#
# `1.`

# %% [markdown]
# > + 111
# + 111
# - 111
# - 111
# * 111
# * 111
